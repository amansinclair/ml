# %%
# %load_ext autoreload
# %autoreload 2

# %%
from cifar_utils import get_datasets, plot, show_preds
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score as acc
from tqdm.notebook import tqdm as bar

# %%
FOLDER = ".//data//cifar//"
training_set, validation_set, mini_set = get_datasets(FOLDER)
print(len(training_set), len(validation_set))
# Out:
# 50000 10000

# %%
plot(training_set.get_image(1), training_set.get_label(1))

# %%
training_gen = DataLoader(training_set, batch_size=32, shuffle=True, num_workers=4)
valid_gen = DataLoader(validation_set, batch_size=len(validation_set))
mini_gen = DataLoader(mini_set, batch_size=32, shuffle=True, num_workers=4)

# %%
net = nn.Sequential(nn.Conv2d(3, 16, 5), nn.ReLU(), nn.MaxPool2d(2), nn.BatchNorm2d(16), nn.Conv2d(16, 32, 3), nn.ReLU(), nn.MaxPool2d(2), nn.BatchNorm2d(32), nn.Conv2d(32, 64, 3), nn.ReLU(), nn.MaxPool2d(2), nn.Flatten(), nn.Linear(256, 10))
crit = nn.CrossEntropyLoss()
opt = optim.Adam(net.parameters())

# %%
def fit(net, crit, opt, train, val, n_epochs=1):
    for epoch in range(n_epochs):
        epoch_loss = []
        epoch_acc = []
        for X, y in bar(train):
            opt.zero_grad()
            p = net(X)
            v, i = p.max(axis=1)
            epoch_acc.append(acc(y, i))
            loss = crit(p, y)
            epoch_loss.append(loss.item())
            loss.backward()
            opt.step()
        with torch.no_grad():
            for X, y in val:
                p = net(X)
                v, i = p.max(axis=1)
                val_loss = crit(p, y).item()
                val_acc = acc(y, i)
        print(f"Epoch:{epoch + 1}, T Loss:{np.mean(epoch_loss):.3f}, T acc:{np.mean(epoch_acc):.3f} V Loss:{np.mean(val_loss):.3f}, V acc:{val_acc:.3f}")

# %%
fit(net, crit, opt, training_gen, valid_gen, 10)

# %%
show_preds(net, valid_gen)
# Out:
# pred frog(cat)
# pred ship(ship)
# pred ship(ship)
# pred ship(airplane)
# pred frog(frog)
# pred cat(frog)
# pred automobile(automobile)
# pred deer(frog)
# pred bird(cat)
# pred automobile(automobile)
# pred airplane(airplane)
# pred truck(truck)
# pred frog(dog)
# pred ship(horse)
# pred automobile(truck)
# pred ship(ship)
# pred dog(dog)
# pred cat(horse)
# pred truck(ship)
# pred frog(frog)
# pred horse(horse)
# pred airplane(airplane)
# pred bird(deer)
# pred automobile(truck)
# pred deer(dog)
# pred bird(bird)
# pred frog(deer)
# pred deer(airplane)
# pred bird(truck)
# pred frog(frog)
# pred dog(frog)
# pred dog(dog)
# pred dog(deer)
# pred frog(dog)
# pred truck(truck)
# pred automobile(bird)
# pred deer(deer)
# pred truck(automobile)
# pred truck(truck)
# pred dog(dog)
# pred airplane(deer)
# pred frog(frog)
# pred dog(dog)
# pred frog(frog)
# pred ship(airplane)
# pred ship(truck)
# pred frog(cat)
# pred ship(truck)
# pred horse(horse)
# pred deer(frog)
# ...
