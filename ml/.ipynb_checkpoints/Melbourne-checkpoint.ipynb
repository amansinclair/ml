# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from utils import train_reg, plot_loss

# %%
PATH = "./data/Melbourne/daily-min-temperatures.txt"
with open(PATH, "r") as f:
    reader = csv.reader(f)
    header = next(reader)
    temps = np.array([temp for date, temp in reader], dtype="float32")
len(temps)
# Out:
# 3650

# %%
plt.figure(figsize=(15, 8))
plt.plot(temps)
plt.show()

# %%
mean_temp = temps.mean()
std_temp = temps.std()
temps = (temps - mean_temp) / std_temp
mean_temp, std_temp
# Out:
# (11.177753, 4.071279)

# %%
def split_data(X, train_perc=0.8):
    train_size = int(train_perc * len(X))
    train = X[:train_size]
    test = X[train_size:]
    return train, test

# %%
train, test = split_data(temps)
train.shape, test.shape
# Out:
# ((2920,), (730,))

# %%
def create_xy(X, size=10):
    blocks = len(X) // size
    x = np.zeros((blocks, size - 1), dtype="float32")
    start = 0
    for block in range(blocks):
        x[block] = X[start:start + size - 1]
        start += size
    y = X[size - 1::size].reshape(-1, 1)
    return torch.from_numpy(x), torch.from_numpy(y)

# %%
x_train, y_train = create_xy(train)
x_test, y_test =  create_xy(test)

# %%
train_gen = DataLoader(TensorDataset(x_train, y_train), batch_size=32, shuffle=True)
test_gen = DataLoader(TensorDataset(x_test, y_test), batch_size=32, shuffle=True)

# %%
net = nn.Sequential(nn.Linear(9, 9), nn.ReLU(), nn.Linear(9, 1))
opt = optim.Adam(net.parameters(), lr=0.001, weight_decay=0.0001)
crit = nn.MSELoss()

# %%
train_loss, test_loss = train_reg(net, crit, opt, train_gen, test_gen, n_epochs=200)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:1, T Loss:1.276, V Loss:0.843
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:2, T Loss:0.941, V Loss:0.820
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:3, T Loss:0.849, V Loss:0.575
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:4, T Loss:0.778, V Loss:0.642
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:5, T Loss:0.700, V Loss:0.505
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:6, T Loss:0.664, V Loss:0.524
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:7, T Loss:0.604, V Loss:0.375
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:8, T Loss:0.673, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:9, T Loss:0.551, V Loss:0.321
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:10, T Loss:0.499, V Loss:0.351
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:11, T Loss:0.585, V Loss:0.344
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:12, T Loss:0.522, V Loss:0.363
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:13, T Loss:0.510, V Loss:0.302
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:14, T Loss:0.504, V Loss:0.377
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:15, T Loss:0.472, V Loss:0.295
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:16, T Loss:0.459, V Loss:0.385
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:17, T Loss:0.500, V Loss:0.370
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:18, T Loss:0.449, V Loss:0.326
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:19, T Loss:0.472, V Loss:0.341
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:20, T Loss:0.483, V Loss:0.296
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:21, T Loss:0.428, V Loss:0.291
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:22, T Loss:0.441, V Loss:0.304
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:23, T Loss:0.426, V Loss:0.287
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:24, T Loss:0.444, V Loss:0.232
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:25, T Loss:0.453, V Loss:0.319
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:26, T Loss:0.463, V Loss:0.315
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:27, T Loss:0.424, V Loss:0.289
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:28, T Loss:0.527, V Loss:0.235
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:29, T Loss:0.453, V Loss:0.239
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:30, T Loss:0.433, V Loss:0.236
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:31, T Loss:0.427, V Loss:0.260
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:32, T Loss:0.396, V Loss:0.231
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:33, T Loss:0.403, V Loss:0.294
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:34, T Loss:0.397, V Loss:0.261
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:35, T Loss:0.431, V Loss:0.250
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:36, T Loss:0.409, V Loss:0.296
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:37, T Loss:0.386, V Loss:0.268
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:38, T Loss:0.430, V Loss:0.229
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:39, T Loss:0.425, V Loss:0.229
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:40, T Loss:0.550, V Loss:0.253
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:41, T Loss:0.415, V Loss:0.260
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:42, T Loss:0.379, V Loss:0.243
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:43, T Loss:0.435, V Loss:0.223
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:44, T Loss:0.407, V Loss:0.224
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:45, T Loss:0.397, V Loss:0.255
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:46, T Loss:0.386, V Loss:0.243
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:47, T Loss:0.366, V Loss:0.234
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:48, T Loss:0.372, V Loss:0.215
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:49, T Loss:0.402, V Loss:0.220
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:50, T Loss:0.393, V Loss:0.255
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:51, T Loss:0.405, V Loss:0.227
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:52, T Loss:0.432, V Loss:0.252
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:53, T Loss:0.390, V Loss:0.245
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:54, T Loss:0.387, V Loss:0.255
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:55, T Loss:0.371, V Loss:0.220
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:56, T Loss:0.430, V Loss:0.271
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:57, T Loss:0.405, V Loss:0.263
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:58, T Loss:0.400, V Loss:0.247
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:59, T Loss:0.374, V Loss:0.279
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:60, T Loss:0.375, V Loss:0.270
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:61, T Loss:0.382, V Loss:0.245
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:62, T Loss:0.374, V Loss:0.291
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:63, T Loss:0.360, V Loss:0.263
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:64, T Loss:0.371, V Loss:0.248
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:65, T Loss:0.444, V Loss:0.205
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:66, T Loss:0.381, V Loss:0.245
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:67, T Loss:0.361, V Loss:0.216
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:68, T Loss:0.380, V Loss:0.223
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:69, T Loss:0.361, V Loss:0.302
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:70, T Loss:0.374, V Loss:0.276
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:71, T Loss:0.440, V Loss:0.285
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:72, T Loss:0.368, V Loss:0.247
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:73, T Loss:0.466, V Loss:0.212
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:74, T Loss:0.403, V Loss:0.249
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:75, T Loss:0.390, V Loss:0.299
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:76, T Loss:0.389, V Loss:0.273
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:77, T Loss:0.365, V Loss:0.231
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:78, T Loss:0.372, V Loss:0.209
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:79, T Loss:0.381, V Loss:0.211
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:80, T Loss:0.416, V Loss:0.247
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:81, T Loss:0.371, V Loss:0.287
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:82, T Loss:0.364, V Loss:0.287
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:83, T Loss:0.392, V Loss:0.196
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:84, T Loss:0.371, V Loss:0.259
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:85, T Loss:0.380, V Loss:0.242
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:86, T Loss:0.366, V Loss:0.267
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:87, T Loss:0.390, V Loss:0.241
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:88, T Loss:0.353, V Loss:0.237
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:89, T Loss:0.375, V Loss:0.247
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:90, T Loss:0.354, V Loss:0.264
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:91, T Loss:0.378, V Loss:0.236
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:92, T Loss:0.428, V Loss:0.255
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:93, T Loss:0.380, V Loss:0.301
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:94, T Loss:0.393, V Loss:0.215
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:95, T Loss:0.366, V Loss:0.251
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:96, T Loss:0.363, V Loss:0.237
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:97, T Loss:0.364, V Loss:0.220
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:98, T Loss:0.409, V Loss:0.274
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:99, T Loss:0.393, V Loss:0.277
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:100, T Loss:0.350, V Loss:0.236
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:101, T Loss:0.363, V Loss:0.267
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:102, T Loss:0.369, V Loss:0.217
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:103, T Loss:0.385, V Loss:0.235
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:104, T Loss:0.353, V Loss:0.270
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:105, T Loss:0.359, V Loss:0.219
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:106, T Loss:0.371, V Loss:0.204
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:107, T Loss:0.358, V Loss:0.234
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:108, T Loss:0.357, V Loss:0.208
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:109, T Loss:0.368, V Loss:0.217
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:110, T Loss:0.348, V Loss:0.246
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:111, T Loss:0.400, V Loss:0.261
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:112, T Loss:0.367, V Loss:0.218
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:113, T Loss:0.345, V Loss:0.262
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:114, T Loss:0.349, V Loss:0.246
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:115, T Loss:0.342, V Loss:0.247
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:116, T Loss:0.393, V Loss:0.231
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:117, T Loss:0.369, V Loss:0.214
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:118, T Loss:0.352, V Loss:0.235
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:119, T Loss:0.344, V Loss:0.253
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:120, T Loss:0.356, V Loss:0.212
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:121, T Loss:0.355, V Loss:0.242
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:122, T Loss:0.428, V Loss:0.278
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:123, T Loss:0.347, V Loss:0.291
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:124, T Loss:0.344, V Loss:0.231
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:125, T Loss:0.349, V Loss:0.222
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:126, T Loss:0.376, V Loss:0.281
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:127, T Loss:0.365, V Loss:0.262
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:128, T Loss:0.391, V Loss:0.264
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:129, T Loss:0.347, V Loss:0.232
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:130, T Loss:0.349, V Loss:0.250
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:131, T Loss:0.372, V Loss:0.227
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:132, T Loss:0.380, V Loss:0.233
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:133, T Loss:0.441, V Loss:0.296
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:134, T Loss:0.357, V Loss:0.286
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:135, T Loss:0.352, V Loss:0.253
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:136, T Loss:0.354, V Loss:0.227
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:137, T Loss:0.376, V Loss:0.219
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:138, T Loss:0.335, V Loss:0.235
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:139, T Loss:0.346, V Loss:0.209
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:140, T Loss:0.362, V Loss:0.251
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:141, T Loss:0.404, V Loss:0.220
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:142, T Loss:0.344, V Loss:0.263
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:143, T Loss:0.369, V Loss:0.224
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:144, T Loss:0.391, V Loss:0.242
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:145, T Loss:0.340, V Loss:0.255
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:146, T Loss:0.358, V Loss:0.289
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:147, T Loss:0.352, V Loss:0.221
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:148, T Loss:0.384, V Loss:0.268
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:149, T Loss:0.348, V Loss:0.293
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:150, T Loss:0.342, V Loss:0.238
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:151, T Loss:0.344, V Loss:0.246
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:152, T Loss:0.334, V Loss:0.230
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:153, T Loss:0.366, V Loss:0.245
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:154, T Loss:0.334, V Loss:0.290
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:155, T Loss:0.346, V Loss:0.307
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:156, T Loss:0.374, V Loss:0.283
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:157, T Loss:0.344, V Loss:0.262
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:158, T Loss:0.348, V Loss:0.240
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:159, T Loss:0.342, V Loss:0.254
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:160, T Loss:0.344, V Loss:0.218
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:161, T Loss:0.344, V Loss:0.240
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:162, T Loss:0.417, V Loss:0.267
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:163, T Loss:0.370, V Loss:0.298
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:164, T Loss:0.339, V Loss:0.309
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:165, T Loss:0.361, V Loss:0.215
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:166, T Loss:0.375, V Loss:0.271
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:167, T Loss:0.351, V Loss:0.255
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:168, T Loss:0.353, V Loss:0.249
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:169, T Loss:0.353, V Loss:0.213
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:170, T Loss:0.348, V Loss:0.255
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:171, T Loss:0.348, V Loss:0.225
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:172, T Loss:0.394, V Loss:0.253
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:173, T Loss:0.333, V Loss:0.286
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:174, T Loss:0.361, V Loss:0.218
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:175, T Loss:0.343, V Loss:0.254
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:176, T Loss:0.362, V Loss:0.245
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:177, T Loss:0.425, V Loss:0.223
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:178, T Loss:0.337, V Loss:0.283
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:179, T Loss:0.337, V Loss:0.233
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:180, T Loss:0.373, V Loss:0.260
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:181, T Loss:0.404, V Loss:0.256
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:182, T Loss:0.344, V Loss:0.253
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:183, T Loss:0.347, V Loss:0.278
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:184, T Loss:0.333, V Loss:0.255
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:185, T Loss:0.335, V Loss:0.240
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:186, T Loss:0.349, V Loss:0.234
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:187, T Loss:0.437, V Loss:0.282
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:188, T Loss:0.352, V Loss:0.244
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:189, T Loss:0.353, V Loss:0.226
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:190, T Loss:0.352, V Loss:0.290
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:191, T Loss:0.335, V Loss:0.236
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:192, T Loss:0.400, V Loss:0.224
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:193, T Loss:0.334, V Loss:0.312
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:194, T Loss:0.340, V Loss:0.338
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:195, T Loss:0.352, V Loss:0.292
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:196, T Loss:0.336, V Loss:0.278
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:197, T Loss:0.355, V Loss:0.239
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:198, T Loss:0.357, V Loss:0.276
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:199, T Loss:0.350, V Loss:0.230
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:200, T Loss:0.335, V Loss:0.283

# %%
def RMSE(true, preds):
    scaled_true = (true * std_temp) + mean_temp
    scaled_preds = (preds* std_temp) + mean_temp
    return (((scaled_true - scaled_preds)**2).mean()**0.5).item()

# %%
preds = net(x_test)

# %%
RMSE(y_test, preds)
# Out:
# 2.608325958251953

# %%
plot_loss(train_loss, test_loss)

# %%
scaled_preds = (preds* std_temp) + mean_temp
scaled_true = (y_test * std_temp) + mean_temp

# %%
plt.figure(figsize=(15, 8))
plt.plot(scaled_true.detach().numpy(), label="True")
plt.plot(scaled_preds.detach().numpy(), "o", label="Pred")
plt.legend()
plt.show()

# %%
class RNN(nn.Module):
    def __init__(self, hidden_size=9):
        super().__init__()
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(1, hidden_size, nonlinearity="tanh", batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        batch_size = x.shape[0]
        hidden = torch.zeros(1, batch_size, self.hidden_size)
        out, hidden = self.rnn(x.unsqueeze(-1), hidden)
        x = self.fc(x.squeeze(-1))
        return x

# %%
rnn_net = RNN(9)

# %%
opt_rnn = optim.Adam(rnn_net.parameters(), lr=0.001, weight_decay=0.0001)

# %%
train_loss, test_loss = train_reg(rnn_net, crit, opt, train_gen, test_gen, n_epochs=100)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:1, T Loss:0.571, V Loss:0.424
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:2, T Loss:0.564, V Loss:0.436
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:3, T Loss:0.588, V Loss:0.350
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:4, T Loss:0.572, V Loss:0.383
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:5, T Loss:0.625, V Loss:0.505
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:6, T Loss:0.583, V Loss:0.488
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:7, T Loss:0.573, V Loss:0.369
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:8, T Loss:0.616, V Loss:0.381
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:9, T Loss:0.555, V Loss:0.377
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Epoch:10, T Loss:0.564, V Loss:0.423

# %%
preds = rnn_net(x_test)

# %%
RMSE(y_test, preds)
# Out:
# tensor(2.6083, grad_fn=<PowBackward0>)

# %%
plot_loss(train_loss, test_loss)

# %%
scaled_preds = (preds* std_temp) + mean_temp
scaled_true = (y_test * std_temp) + mean_temp

# %%
plt.figure(figsize=(15, 8))
plt.plot(scaled_true.detach().numpy(), label="True")
plt.plot(scaled_preds.detach().numpy(), "o", label="Pred")
plt.legend()
plt.show()
