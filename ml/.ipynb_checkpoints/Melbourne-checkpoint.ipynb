# %% [markdown]
# #  Predicting minimum daily temperatures in Melbourne
# Predict the minimum daily temperature for the next 7 days given the historic minimum daily averages and the 7 days leading up. Simple model performs **0.24 deg** better than historic averages.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from utils import train as train_loop
from utils import plot_loss

# %%
PATH = "./data/Melbourne/daily-min-temperatures.txt"
with open(PATH, "r") as f:
    reader = csv.reader(f)
    header = next(reader)
    temps = []
    dates = []
    for date, temp in reader:
        temps.append(temp)
        dates.append(date)
    temps = np.array(temps, dtype="float32")
len(temps)
# Out:
# 3650

# %%
print(dates[1458:1462]) # no 31st Dec due to leap year
# Out:
# ['1984-12-29', '1984-12-30', '1985-01-01', '1985-01-02']

# %%
years = temps.reshape(-1, 365)
print(f"Mean Daily Variation: {years.std(axis=0).mean()}")
plt.figure(figsize=(15, 8))
for year in years:
    plt.plot(year)
plt.show()
# Out:
# Mean Daily Variation: 2.544987440109253

# %%
plt.figure(figsize=(15, 8))
m = years[:-1].mean(axis=0)
std = years[:-1].std(axis=0)
plt.plot(m, label="mean of first 8 years")
plt.fill_between(np.arange(365), m - std, m + std, color='blue', alpha=0.2)
plt.plot(years[-1], "x", label="last year")
plt.legend()
plt.show()

# %%
def split_data(temps, dates, train_years):
    break_year = str(90 - train_years + 1)
    for i, date in enumerate(dates):
        if break_year in date:
            break    
    train = temps[:i]
    test = temps[i:]
    return train, test

# %%
train, test = split_data(temps, dates, 1)
train.shape, test.shape
# Out:
# ((3285,), (365,))

# %%
temp_mean = train.mean()
temp_std = train.std()
train = (train - temp_mean) / temp_std
test = (test - temp_mean) / temp_std
historic_means = train.reshape((-1, 365)).mean(axis=0)
historic_means.shape
# Out:
# (365,)

# %%
PREDICT_PERIOD = 7
LEARNING_PERIOD = 7

# %%
def create_xy(X, means, learning_size=7):
    block_size = learning_size + PREDICT_PERIOD
    blocks = len(X) // (block_size)
    x = np.zeros((blocks, block_size), dtype="float32")
    y = np.zeros((blocks, PREDICT_PERIOD), dtype="float32")
    start = 0
    for block in range(blocks):
        end = start + block_size
        split = start + learning_size
        input_temps = X[start: split]
        y[block] = X[split: end]
        hist_idx = (split % 365)
        if hist_idx + PREDICT_PERIOD > 365:
            h_end = hist_idx + PREDICT_PERIOD - 365
            hist_temps = np.concatenate((means[hist_idx:], means[:h_end]))
        else:
            hist_temps = means[hist_idx: hist_idx + PREDICT_PERIOD]
        x[block] = np.concatenate((input_temps, hist_temps))
        start = end
    return torch.from_numpy(x), torch.from_numpy(y)

# %%
x_train, y_train = create_xy(train, historic_means, LEARNING_PERIOD)
x_test, y_test =  create_xy(test, historic_means, LEARNING_PERIOD)
x_train.shape, x_test.shape
# Out:
# (torch.Size([234, 14]), torch.Size([26, 14]))

# %%
train_gen = DataLoader(TensorDataset(x_train, y_train), batch_size=32, shuffle=True)
test_gen = DataLoader(TensorDataset(x_test, y_test), batch_size=32, shuffle=True)

# %%
size = 8
net = nn.Sequential(nn.Linear(x_train.shape[1], size), nn.ReLU(), nn.Linear(size, PREDICT_PERIOD))
opt = optim.Adam(net.parameters(), lr=0.001, weight_decay=0.0001)
crit = nn.MSELoss()

# %%
train_loss, _, test_loss, _, = train_loop(net, crit, opt, train_gen, test_gen, n_epochs=60)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:1, T Loss:1.064, V Loss:0.937
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:2, T Loss:1.025, V Loss:0.911
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:3, T Loss:0.974, V Loss:0.888
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:4, T Loss:0.935, V Loss:0.861
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:5, T Loss:0.908, V Loss:0.835
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:6, T Loss:0.903, V Loss:0.805
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:7, T Loss:0.894, V Loss:0.772
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:8, T Loss:0.817, V Loss:0.736
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:9, T Loss:0.800, V Loss:0.701
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:10, T Loss:0.742, V Loss:0.665
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:11, T Loss:0.732, V Loss:0.630
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:12, T Loss:0.681, V Loss:0.593
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:13, T Loss:0.666, V Loss:0.558
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:14, T Loss:0.607, V Loss:0.524
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:15, T Loss:0.591, V Loss:0.496
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:16, T Loss:0.576, V Loss:0.469
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:17, T Loss:0.535, V Loss:0.448
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:18, T Loss:0.532, V Loss:0.430
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:19, T Loss:0.512, V Loss:0.415
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:20, T Loss:0.495, V Loss:0.402
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:21, T Loss:0.486, V Loss:0.392
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:22, T Loss:0.475, V Loss:0.384
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:23, T Loss:0.470, V Loss:0.377
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:24, T Loss:0.478, V Loss:0.372
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:25, T Loss:0.466, V Loss:0.368
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:26, T Loss:0.449, V Loss:0.365
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:27, T Loss:0.452, V Loss:0.363
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:28, T Loss:0.447, V Loss:0.361
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:29, T Loss:0.447, V Loss:0.360
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:30, T Loss:0.432, V Loss:0.359
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:31, T Loss:0.455, V Loss:0.357
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:32, T Loss:0.438, V Loss:0.355
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:33, T Loss:0.432, V Loss:0.354
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:34, T Loss:0.435, V Loss:0.353
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:35, T Loss:0.438, V Loss:0.352
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:36, T Loss:0.437, V Loss:0.352
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:37, T Loss:0.429, V Loss:0.352
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:38, T Loss:0.428, V Loss:0.351
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:39, T Loss:0.430, V Loss:0.352
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:40, T Loss:0.416, V Loss:0.352
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:41, T Loss:0.422, V Loss:0.350
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:42, T Loss:0.417, V Loss:0.349
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:43, T Loss:0.417, V Loss:0.349
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:44, T Loss:0.421, V Loss:0.348
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:45, T Loss:0.439, V Loss:0.348
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:46, T Loss:0.418, V Loss:0.348
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:47, T Loss:0.422, V Loss:0.348
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:48, T Loss:0.418, V Loss:0.348
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:49, T Loss:0.419, V Loss:0.348
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:50, T Loss:0.418, V Loss:0.347
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:51, T Loss:0.425, V Loss:0.347
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:52, T Loss:0.417, V Loss:0.347
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:53, T Loss:0.417, V Loss:0.346
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:54, T Loss:0.412, V Loss:0.345
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:55, T Loss:0.422, V Loss:0.345
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:56, T Loss:0.407, V Loss:0.346
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:57, T Loss:0.425, V Loss:0.346
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:58, T Loss:0.417, V Loss:0.345
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:59, T Loss:0.423, V Loss:0.344
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:60, T Loss:0.405, V Loss:0.344

# %%
plot_loss(train_loss, test_loss)

# %%
def RMSE(true, preds):
    scaled_true = (true * temp_std) + temp_mean
    scaled_preds = (preds* temp_std) + temp_mean
    daily_rmse = (((scaled_true - scaled_preds)**2).mean(dim=0)**0.5)
    return daily_rmse, daily_rmse.mean().item()

# %%
def predict_last(X):
    return X[:,-PREDICT_PERIOD:]

# %%
def simple_pred(X):
    hist = X[:,-PREDICT_PERIOD:]
    guess = np.repeat(X[:,-PREDICT_PERIOD - 1], PREDICT_PERIOD).reshape(-1, PREDICT_PERIOD)
    return (hist + guess) / 2

# %%
net_preds = net(x_test)
hist_preds = predict_last(x_test)
simp_preds = simple_pred(x_test)

# %%
net_daily_acc, net_acc = RMSE(y_test, net_preds)
hist_daily_acc, hist_acc = RMSE(y_test, hist_preds)
simple_daily_acc, simple_acc = RMSE(y_test, simp_preds)
print(f"pred_rmse:{net_acc:.3f}, hist_rmse:{hist_acc:.3f}, simple_rmse:{simple_acc:.3f}, diff:{abs(net_acc - hist_acc):.3f}")
plt.figure(figsize=(15, 8))
plt.plot(net_daily_acc.detach().numpy(), label="pred")
plt.plot(hist_daily_acc.detach().numpy(), label="hist")
plt.plot(simple_daily_acc.detach().numpy(), label="simp")
plt.legend()
plt.show()
# Out:
# pred_rmse:2.373, hist_rmse:2.612, simple_rmse:2.590, diff:0.239

# %%
def plot_preds(y_true, preds, nrows=5):
    scaled_preds = (preds* temp_std) + temp_mean
    scaled_true = (y_true * temp_std) + temp_mean
    fig, axes = plt.subplots(nrows, 1, figsize=(15, 10))
    for i, ax in enumerate(axes):
        ax.plot(scaled_true[i].detach().numpy(), label="True")
        ax.plot(scaled_preds[i].detach().numpy(), "o", label="Pred")
    plt.legend()
    plt.show()

# %%
plot_preds(y_test, net_preds)
