# %% [markdown]
# #  Predicting minimum daily temperatures in Melbourne
# Predict the minimum daily temperature for the next 7 days given the historic minimum daily averages and the 7 days leading up. Simple model performs **0.22 deg** better than historic averages.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from utils import train_reg, plot_loss

# %%
PATH = "./data/Melbourne/daily-min-temperatures.txt"
with open(PATH, "r") as f:
    reader = csv.reader(f)
    header = next(reader)
    temps = []
    dates = []
    for date, temp in reader:
        temps.append(temp)
        dates.append(date)
    temps = np.array(temps, dtype="float32")
len(temps)
# Out:
# 3650

# %%
print(dates[1458:1462]) # no 31st Dec due to leap year
# Out:
# ['1984-12-29', '1984-12-30', '1985-01-01', '1985-01-02']

# %%
years = temps.reshape(-1, 365)
print(f"Mean Daily Variation: {years.std(axis=0).mean()}")
plt.figure(figsize=(15, 8))
for year in years:
    plt.plot(year)
plt.show()
# Out:
# Mean Daily Variation: 2.544987440109253

# %%
plt.figure(figsize=(15, 8))
m = years[:-1].mean(axis=0)
std = years[:-1].std(axis=0)
plt.plot(m, label="mean of first 8 years")
plt.fill_between(np.arange(365), m - std, m + std, color='blue', alpha=0.2)
plt.plot(years[-1], "x", label="last year")
plt.legend()
plt.show()

# %%
def split_data(temps, dates, train_years):
    break_year = str(90 - train_years + 1)
    for i, date in enumerate(dates):
        if break_year in date:
            break    
    train = temps[:i]
    test = temps[i:]
    return train, test

# %%
train, test = split_data(temps, dates, 1)
train.shape, test.shape
# Out:
# ((3285,), (365,))

# %%
temp_mean = train.mean()
temp_std = train.std()
train = (train - mean_temp) / temp_std
test = (test - mean_temp) / temp_std
historic_means = train.reshape((-1, 365)).mean(axis=0)
historic_means.shape
# Out:
# (365,)

# %%
PREDICT_PERIOD = 7
LEARNING_PERIOD = 7

# %%
def create_xy(X, means, learning_size=7):
    block_size = learning_size + PREDICT_PERIOD
    blocks = len(X) // (block_size)
    x = np.zeros((blocks, block_size), dtype="float32")
    y = np.zeros((blocks, PREDICT_PERIOD), dtype="float32")
    start = 0
    for block in range(blocks):
        end = start + block_size
        split = start + learning_size
        input_temps = X[start: split]
        y[block] = X[split: end]
        hist_idx = (split % 365)
        if hist_idx + PREDICT_PERIOD > 365:
            h_end = hist_idx + PREDICT_PERIOD - 365
            hist_temps = np.concatenate((means[hist_idx:], means[:h_end]))
        else:
            hist_temps = means[hist_idx: hist_idx + PREDICT_PERIOD]
        x[block] = np.concatenate((input_temps, hist_temps))
        start = end
    return torch.from_numpy(x), torch.from_numpy(y)

# %%
x_train, y_train = create_xy(train, historic_means, LEARNING_PERIOD)
x_test, y_test =  create_xy(test, historic_means, LEARNING_PERIOD)
x_train.shape, x_test.shape
# Out:
# (torch.Size([234, 14]), torch.Size([26, 14]))

# %%
train_gen = DataLoader(TensorDataset(x_train, y_train), batch_size=32, shuffle=True)
test_gen = DataLoader(TensorDataset(x_test, y_test), batch_size=32, shuffle=True)

# %%
size = 8
net = nn.Sequential(nn.Linear(x_train.shape[1], size), nn.ReLU(), nn.Linear(size, PREDICT_PERIOD))
opt = optim.Adam(net.parameters(), lr=0.001, weight_decay=0.0001)
crit = nn.MSELoss()

# %%
train_loss, test_loss = train_reg(net, crit, opt, train_gen, test_gen, n_epochs=100)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:1, T Loss:0.943, V Loss:0.806
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:2, T Loss:0.915, V Loss:0.769
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:3, T Loss:0.866, V Loss:0.736
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:4, T Loss:0.833, V Loss:0.706
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:5, T Loss:0.776, V Loss:0.676
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:6, T Loss:0.784, V Loss:0.646
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:7, T Loss:0.734, V Loss:0.616
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:8, T Loss:0.718, V Loss:0.586
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:9, T Loss:0.672, V Loss:0.555
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:10, T Loss:0.650, V Loss:0.528
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:11, T Loss:0.635, V Loss:0.500
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:12, T Loss:0.596, V Loss:0.474
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:13, T Loss:0.593, V Loss:0.450
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:14, T Loss:0.542, V Loss:0.429
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:15, T Loss:0.530, V Loss:0.411
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:16, T Loss:0.521, V Loss:0.396
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:17, T Loss:0.514, V Loss:0.386
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:18, T Loss:0.488, V Loss:0.377
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:19, T Loss:0.474, V Loss:0.370
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:20, T Loss:0.470, V Loss:0.363
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:21, T Loss:0.462, V Loss:0.358
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:22, T Loss:0.476, V Loss:0.354
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:23, T Loss:0.445, V Loss:0.351
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:24, T Loss:0.469, V Loss:0.349
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:25, T Loss:0.445, V Loss:0.347
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:26, T Loss:0.437, V Loss:0.345
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:27, T Loss:0.437, V Loss:0.343
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:28, T Loss:0.460, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:29, T Loss:0.428, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:30, T Loss:0.431, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:31, T Loss:0.439, V Loss:0.341
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:32, T Loss:0.430, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:33, T Loss:0.418, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:34, T Loss:0.427, V Loss:0.339
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:35, T Loss:0.420, V Loss:0.339
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:36, T Loss:0.425, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:37, T Loss:0.431, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:38, T Loss:0.425, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:39, T Loss:0.421, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:40, T Loss:0.426, V Loss:0.341
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:41, T Loss:0.431, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:42, T Loss:0.411, V Loss:0.339
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:43, T Loss:0.411, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:44, T Loss:0.417, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:45, T Loss:0.417, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:46, T Loss:0.423, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:47, T Loss:0.419, V Loss:0.341
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:48, T Loss:0.414, V Loss:0.341
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:49, T Loss:0.413, V Loss:0.341
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:50, T Loss:0.414, V Loss:0.341
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:51, T Loss:0.413, V Loss:0.341
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:52, T Loss:0.411, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:53, T Loss:0.418, V Loss:0.340
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:54, T Loss:0.416, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:55, T Loss:0.412, V Loss:0.341
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:56, T Loss:0.416, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:57, T Loss:0.414, V Loss:0.343
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:58, T Loss:0.416, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:59, T Loss:0.404, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:60, T Loss:0.407, V Loss:0.341
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:61, T Loss:0.414, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:62, T Loss:0.408, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:63, T Loss:0.403, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:64, T Loss:0.412, V Loss:0.343
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:65, T Loss:0.415, V Loss:0.344
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:66, T Loss:0.412, V Loss:0.343
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:67, T Loss:0.404, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:68, T Loss:0.413, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:69, T Loss:0.414, V Loss:0.342
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:70, T Loss:0.405, V Loss:0.343
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:71, T Loss:0.413, V Loss:0.344
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:72, T Loss:0.406, V Loss:0.345
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:73, T Loss:0.405, V Loss:0.344
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:74, T Loss:0.394, V Loss:0.344
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:75, T Loss:0.396, V Loss:0.344
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:76, T Loss:0.417, V Loss:0.344
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:77, T Loss:0.412, V Loss:0.345
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:78, T Loss:0.395, V Loss:0.346
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:79, T Loss:0.407, V Loss:0.346
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:80, T Loss:0.401, V Loss:0.345
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:81, T Loss:0.400, V Loss:0.344
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:82, T Loss:0.414, V Loss:0.345
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:83, T Loss:0.394, V Loss:0.346
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:84, T Loss:0.402, V Loss:0.346
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:85, T Loss:0.393, V Loss:0.346
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:86, T Loss:0.392, V Loss:0.346
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:87, T Loss:0.401, V Loss:0.347
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:88, T Loss:0.390, V Loss:0.347
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:89, T Loss:0.401, V Loss:0.347
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:90, T Loss:0.403, V Loss:0.347
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:91, T Loss:0.410, V Loss:0.348
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:92, T Loss:0.413, V Loss:0.350
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:93, T Loss:0.401, V Loss:0.350
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:94, T Loss:0.400, V Loss:0.350
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:95, T Loss:0.399, V Loss:0.350
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:96, T Loss:0.397, V Loss:0.351
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:97, T Loss:0.396, V Loss:0.351
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:98, T Loss:0.406, V Loss:0.351
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:99, T Loss:0.399, V Loss:0.350
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# Epoch:100, T Loss:0.406, V Loss:0.349

# %%
plot_loss(train_loss, test_loss)

# %%
def RMSE(true, preds):
    scaled_true = (true * std_temp) + mean_temp
    scaled_preds = (preds* std_temp) + mean_temp
    daily_rmse = (((scaled_true - scaled_preds)**2).mean(dim=0)**0.5)
    return daily_rmse, daily_rmse.mean().item()

# %%
def predict_last(X):
    return X[:,-PREDICT_PERIOD:]

# %%
def simple_pred(X):
    hist = X[:,-PREDICT_PERIOD:]
    guess = np.repeat(X[:,-PREDICT_PERIOD - 1], PREDICT_PERIOD).reshape(-1, PREDICT_PERIOD)
    return (hist + guess) / 2

# %%
net_preds = net(x_test)
hist_preds = predict_last(x_test)
simp_preds = simple_pred(x_test)

# %%
net_daily_acc, net_acc = RMSE(y_test, net_preds)
hist_daily_acc, hist_acc = RMSE(y_test, hist_preds)
simple_daily_acc, simple_acc = RMSE(y_test, simp_preds)
print(f"pred_rmse:{net_acc:.3f}, hist_rmse:{hist_acc:.3f}, simple_rmse:{simple_acc:.3f}, diff:{abs(net_acc - hist_acc):.3f}")
plt.figure(figsize=(15, 8))
plt.plot(net_daily_acc.detach().numpy(), label="pred")
plt.plot(hist_daily_acc.detach().numpy(), label="hist")
plt.plot(simple_daily_acc.detach().numpy(), label="simp")
plt.legend()
plt.show()
# Out:
# pred_rmse:2.375, hist_rmse:2.599, simple_rmse:2.577, diff:0.225

# %%
def plot_preds(y_true, preds, nrows=5):
    scaled_preds = (preds* std_temp) + mean_temp
    scaled_true = (y_true * std_temp) + mean_temp
    fig, axes = plt.subplots(nrows, 1, figsize=(15, 10))
    for i, ax in enumerate(axes):
        ax.plot(scaled_true[i].detach().numpy(), label="True")
        ax.plot(scaled_preds[i].detach().numpy(), "o", label="Pred")
    plt.legend()
    plt.show()

# %%
plot_preds(y_test, net_preds)
